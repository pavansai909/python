# %%
import pandas as pd

# %%
df1 = pd.read_csv('Telcom_dataset.csv')
df2= pd.read_csv('Telcom_dataset2.csv')
df3 = pd.read_csv('Telcom_dataset3.csv')

# %%
df1.head()
df1.columns = ['PRODUCT','VALUE','DATETIME','CELL_ON_SITE','DW_A_NUMBER','DW_B_NUMBER','COUNTRY_A','COUNTRY_B','CELL_ID','SITE_ID']
# Out:
#      PRODUCT  VALUE               DATETIME CELL_ON_SITE      DW_A_NUMBER  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#           DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
df2.columns = ['PRODUCT','VALUE','DATETIME','CELL_ON_SITE','DW_A_NUMBER','DW_B_NUMBER','COUNTRY_A','COUNTRY_B','CELL_ID','SITE_ID']
df2.head()
# Out:
#   PRODUCT  VALUE               DATETIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
df3.columns = ['PRODUCT','VALUE','DATETIME','CELL_ON_SITE','DW_A_NUMBER','DW_B_NUMBER','COUNTRY_A','COUNTRY_B','CELL_ID','SITE_ID']
df3.head()
# Out:
#   PRODUCT  VALUE               DATETIME CELL_ON_SITE      DW_A_NUMBER  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
df4 = pd.read_csv('cells_geo (1).csv',delimiter = ';')
df4.head()
# Out:
#    Unnamed: 0   VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  \
# 0           0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
# 1           1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
# 2           2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
# 3           3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"
# 4           4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"
#
#    LONGITUDE  LATITUDE     REGION AREA     CELL_ID   SITE_CODE
# 0  -4.000667  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17
# 1  -4.000667  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17
# 2  -4.000667  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17
# 3  -3.488467  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f
# 4  -3.488467  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f

# %%
merged = pd.concat([df1,df2,df3])
merged
# Out:
#      PRODUCT  VALUE               DATETIME CELL_ON_SITE      DW_A_NUMBER  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#           DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15003 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       15003 non-null  object
#  1   VALUE         15003 non-null  int64
#  2   DATETIME      15003 non-null  object
#  3   CELL_ON_SITE  15003 non-null  object
#  4   DW_A_NUMBER   15003 non-null  object
#  5   DW_B_NUMBER   15003 non-null  object
#  6   COUNTRY_A     15003 non-null  object
#  7   COUNTRY_B     15003 non-null  object
#  8   CELL_ID       15003 non-null  object
#  9   SITE_ID       13006 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.3+ MB

# %%
merged.isnull().sum()
# Out:
# PRODUCT            0
# VALUE              0
# DATETIME           0
# CELL_ON_SITE       0
# DW_A_NUMBER        0
# DW_B_NUMBER        0
# COUNTRY_A          0
# COUNTRY_B          0
# CELL_ID            0
# SITE_ID         1997
# dtype: int64

# %%
df4.columns = ['0', 'CITY', 'STATUS', 'LOCALISATION', 'DECOUPZONE', 'ZONENAME', 'LONGITUDE', 'LATITUDE', 'REGION', 'AREA', 'CELL_ID', 'SITE_ID']
df4.head()
# Out:
#    0     CITY      STATUS LOCALISATION    DECOUPZONE  ZONENAME  LONGITUDE  \
# 0  0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 1  1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 2  2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 3  3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# 4  4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
#
#    LATITUDE     REGION AREA     CELL_ID     SITE_ID
# 0  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17
# 1  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17
# 2  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17
# 3  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f
# 4  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3974 entries, 0 to 3973
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    3974 non-null   int64
#  1   VILLES        3974 non-null   object
#  2   STATUS        3907 non-null   object
#  3   LOCALISATION  3974 non-null   object
#  4   DECOUPZONE    3974 non-null   object
#  5   ZONENAME      3968 non-null   object
#  6   LONGITUDE     3974 non-null   float64
#  7   LATITUDE      3974 non-null   float64
#  8   REGION        3974 non-null   object
#  9   AREA          3951 non-null   object
#  10  CELL_ID       3974 non-null   object
#  11  SITE_CODE     3974 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 372.7+ KB

# %%
df4.isnull().sum()
# Out:
# Unnamed: 0       0
# VILLES           0
# STATUS          67
# LOCALISATION     0
# DECOUPZONE       0
# ZONENAME         6
# LONGITUDE        0
# LATITUDE         0
# REGION           0
# AREA            23
# CELL_ID          0
# SITE_CODE        0
# dtype: int64

# %%
df4['STATUS'].fillna('In Service',inplace =True)
df4.isnull().sum()
# Out:
# Unnamed: 0       0
# VILLES           0
# STATUS           0
# LOCALISATION     0
# DECOUPZONE       0
# ZONENAME         6
# LONGITUDE        0
# LATITUDE         0
# REGION           0
# AREA            23
# CELL_ID          0
# SITE_CODE        0
# dtype: int64

# %%
merged.isnull().sum()
# Out:
# PRODUCT            0
# VALUE              0
# DATETIME           0
# CELL_ON_SITE       0
# DW_A_NUMBER        0
# DW_B_NUMBER        0
# COUNTRY_A          0
# COUNTRY_B          0
# CELL_ID            0
# SITE_ID         1997
# dtype: int64

# %%
merged.head(1)
# Out:
#   PRODUCT  VALUE               DATETIME CELL_ON_SITE      DW_A_NUMBER  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu

# %%
df4.head(1)
# Out:
#    Unnamed: 0  VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  \
# 0           0  ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW
#
#    LONGITUDE  LATITUDE  REGION AREA     CELL_ID   SITE_CODE
# 0  -4.000667  5.368194  LAGUNE  NaN  fbb2e75af3  0bb492ef17

# %%
merged.duplicated()
merged.drop_duplicates(inplace=True)
merged
# Out:
#      PRODUCT  VALUE               DATETIME CELL_ON_SITE      DW_A_NUMBER  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4995   Voice     10  2012-05-09 00:01:43.0            0  2f834987f0c1825
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#           DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
# Most used city for the three days
# since we have site id  on both merged and df4,
#we can used it to find which sites were most used and the use the side to locate the cities

merged['SITE_ID'].value_counts()

#from the results it cleary shows hoe many times a given site has been used.
# Out:
# 7f76d66503    110
# b47a998a3e     98
# a7bd4c027b     79
# 5c565fbfb1     75
# 91e86be9a6     72
#              ...
# HDTX65E7ic      1
# PYgURTUHcG      1
# QopBUmndlf      1
# PohuYomFPJ      1
# ab91f5b21d      1
# Name: SITE_ID, Length: 1357, dtype: int64

# %%
#now we can go ahead and find out which city do the most used site  belong. 
value = ['7f76d66503']
df4[df4['SITE_ID'].isin(value)]

#now we can conclude by saying that the most used cities is "ATTECOUBE"
# Out:
#          0       CITY      STATUS LOCALISATION     DECOUPZONE  \
# 1024  1024  ATTECOUBE  In Service      ABIDJAN  Abidjan_OUEST
# 1025  1025  ATTECOUBE  In Service      ABIDJAN  Abidjan_OUEST
# 1026  1026  ATTECOUBE  In Service      ABIDJAN  Abidjan_OUEST
# 1027  1027  ATTECOUBE  In Service      ABIDJAN  Abidjan_OUEST
# 1028  1028  ATTECOUBE  In Service      ABIDJAN  Abidjan_OUEST
# 1029  1029  ATTECOUBE  In Service      ABIDJAN  Abidjan_OUEST
#
#                     ZONENAME  LONGITUDE  LATITUDE  REGION           AREA  \
# 1024  ZONE C - Abidjan_OUEST  -4.035111  5.348917  LAGUNE  ABIDJAN NORTH
# 1025  ZONE C - Abidjan_OUEST  -4.035111  5.348917  LAGUNE  ABIDJAN NORTH
# 1026  ZONE C - Abidjan_OUEST  -4.035111  5.348917  LAGUNE  ABIDJAN NORTH
# 1027  ZONE C - Abidjan_OUEST  -4.035111  5.348917  LAGUNE  ABIDJAN NORTH
# 1028  ZONE C - Abidjan_OUEST  -4.035111  5.348917  LAGUNE  ABIDJAN NORTH
# 1029  ZONE C - Abidjan_OUEST  -4.035111  5.348917  LAGUNE  ABIDJAN NORTH
#
# ...

# %%
#Which cities were the most used during business and home hours

merged.info()
 
# we realise that the date colum it an onject and so we have to convert it to a date time datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14750 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       14750 non-null  object
#  1   VALUE         14750 non-null  int64
#  2   DATETIME      14750 non-null  object
#  3   CELL_ON_SITE  14750 non-null  object
#  4   DW_A_NUMBER   14750 non-null  object
#  5   DW_B_NUMBER   14750 non-null  object
#  6   COUNTRY_A     14750 non-null  object
#  7   COUNTRY_B     14750 non-null  object
#  8   CELL_ID       14750 non-null  object
#  9   SITE_ID       12789 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# converting the column DATATIME from object datatype to datetime datatype

merged["DATETIME"]= pd.to_datetime(merged["DATETIME"])
merged.info()

#The column DATETIME datatype ha snow been changed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14750 entries, 0 to 5000
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT       14750 non-null  object
#  1   VALUE         14750 non-null  int64
#  2   DATETIME      14750 non-null  datetime64[ns]
#  3   CELL_ON_SITE  14750 non-null  object
#  4   DW_A_NUMBER   14750 non-null  object
#  5   DW_B_NUMBER   14750 non-null  object
#  6   COUNTRY_A     14750 non-null  object
#  7   COUNTRY_B     14750 non-null  object
#  8   CELL_ID       14750 non-null  object
#  9   SITE_ID       12789 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
#At this point we can now find the usage in the there days between office hours and home hours 

# Lets start by looking at working hours..

working_hrs = merged[(merged['DATETIME'].dt.hour >= 8) & (merged['DATETIME'].dt.hour <= 17)] ["PRODUCT"].value_counts()
working_hrs

#from the output we realise that no product was used used during the buisness hours.
#so this means that its either people dont use their phones during the business hours or,
# Out:
# Series([], Name: PRODUCT, dtype: int64)

# %%
#now we can look at home hours

after_work = merged[(merged['DATETIME'].dt.hour >= 17) & (merged['DATETIME'].dt.hour <= 24)] ["PRODUCT"].value_counts()
before_work= merged[(merged['DATETIME'].dt.hour >= 0) & (merged['DATETIME'].dt.hour < 8)] ["PRODUCT"].value_counts()

home_hours = after_work + before_work
home_hours

#we realise that each product was used during this hours which means
#1. the date collected may have been for the homehours only or in this cities people use there phones during home hours only
#2. the results also show that the most product that is used is sms so the company can thinkmof investing more on sms
# Out:
# sms      6950
# Voice    5570
# data     2230
# Name: PRODUCT, dtype: int64
